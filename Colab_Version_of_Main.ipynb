# %% [markdown]
# ## Honest-but-Curious Nets (ACM CCS'21)
#
# https://github.com/mmalekzadeh/honest-but-curious-nets
#
# This notebook is prepared for those who want to run an expermints on Google Colab GPUs.
# > The result is the same as running `main.py` on your machine.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount= True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install torch==1.9.1

# %% [markdown]
# I assume that you have copied the [GitHub Folder](https://github.com/mmalekzadeh/honest-but-curious-nets) in your Google drive. So, we just open the directory:

# %%
cd gdrive/My\ Drive/honest-but-curious-nets
# Out:
# /content/gdrive/My Drive/honest-but-curious-nets

# %%
import sys
sys.path.append(".")

# %%
import os
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader, TensorDataset
from torchsummary import summary
import copy
import torchvision 
##
from hbcnets import datasets, models, utils, trainers, constants
## Optional: For making your results reproducible
# torch.manual_seed(constants.RANDOM_SEED)
# torch.cuda.manual_seed(constants.RANDOM_SEED)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False
# np.random.seed(constants.RANDOM_SEED)

# %%
print(torch.__version__)
# Out:
# 1.9.1+cu102

# %% [markdown]
# Here I copied the file `setting.py` in a way that I can pass the desired `args` to the `main(args)` method.
# > This will do the same thing as we do with `from setting import args_parser`

# %%
import argparse
parser = argparse.ArgumentParser()

## Training parameters
parser.add_argument('--server_epochs', type=int, default=50,
                    help="Number of Epochs")    
parser.add_argument('--server_batch', type=int, default=100,
                    help="Batch Size")
parser.add_argument('--server_lr', type=int, default=0.001,
                    help="Learning Rate")                                                    

## Attack Type
parser.add_argument('--attack', type=str, default="parameterized",
                    help="either 'parameterized' or 'regularized'")  

## Etc.
parser.add_argument('--root_dir', type=str, default="hbcnets",
                    help="The root directory for saving data and results.")    
parser.add_argument('--gpu', default=0, 
                    help="When using GPU, set --gpu=0")
parser.add_argument('--device', default='cuda', 
                    help="When using GPU, set --device='cuda'")

args = parser.parse_args([])

# %% [markdown]
# The below is exactly the `main.py`, but as a method.

# %%
# if __name__ == '__main__':
def main(args):
        
    # args = args_parser() ## Reading the input arguments (see setting.py)
    if args.gpu:
        torch.cuda.set_device(args.gpu)
    ## Fetch the datasets
    if constants.DATASET == "utk_face":
        (train_images, train_labels), (test_images, test_labels) = datasets.get_dataset(args)     
        train_labels, test_labels = datasets.prepare_labels(train_labels, test_labels)  
        train_labels = train_labels[:,[constants.HONEST,constants.CURIOUS]].astype(int)
        test_labels  =  test_labels[:,[constants.HONEST,constants.CURIOUS]].astype(int)
        train_dataset = (train_images, train_labels)    
    elif constants.DATASET == "celeba":
        (train_images, train_labels), (valid_images, valid_labels), (test_images, test_labels) = datasets.get_dataset(args)
        train_labels, valid_labels, test_labels = datasets.prepare_labels(train_labels, test_labels, valid_labels)
        train_dataset = ((train_images, train_labels), (valid_images, valid_labels))    

    print("\n*** Dataset's Info") 
    print("Training")
    utils.print_dataset_info((train_images, train_labels))
    if constants.DATASET == "celeba":
        print("Validation")
        utils.print_dataset_info((valid_images, valid_labels))
    print("Testing")
    utils.print_dataset_info((test_images, test_labels))                    
      

    ## For logging
    exp_name = str(constants.HONEST)+"_"+str(constants.CURIOUS)+"_"+str(constants.K_Y)+\
                "_"+str(constants.K_S)+"_"+str(int(constants.BETA_X))+"_"+str(int(constants.BETA_Y))+\
                "_"+str(constants.SOFTMAX)+"/"+str(constants.IMAGE_SIZE)+"_"+str(constants.RANDOM_SEED) 

    ## Model
    model = models.Classifier(num_classes=constants.K_Y, with_softmax=constants.SOFTMAX)        
    model.to(args.device)
    summary(model, input_size=(3, constants.IMAGE_SIZE, constants.IMAGE_SIZE),device=args.device)            
                 
    if args.attack == "parameterized":
        param_G = models.Parameterized(num_inputs=constants.K_Y, num_classes=constants.K_S)        
        param_G.to(args.device)
        summary(param_G, input_size=(constants.K_Y,), device=args.device)       

        save_dir = args.root_dir+"/results_par/"+constants.DATASET+"/"+exp_name+"/"
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)            
        model, param_G = trainers.train_model_par(args, model, param_G, train_dataset, save_dir)  

        ## Test    
        model.load_state_dict(torch.load(save_dir+"best_model.pt", map_location=torch.device(args.device)))         
        param_G.load_state_dict(torch.load(save_dir+"best_param_G.pt", map_location=torch.device(args.device)))         
        test_data_loader = DataLoader(TensorDataset(torch.Tensor(test_images), torch.Tensor(test_labels).long()),
                                batch_size=len(test_images)//50, shuffle=False, drop_last=False)  
        eval_acc_1, eval_acc_2, cf_mat_1, cf_mat_2  = utils.evaluate_acc_par(args, model, param_G, test_data_loader, cf_mat=True, roc=False)
        print("\n$$$ Test Accuracy of the BEST model Y {:.2f}".format(eval_acc_1))
        print("     Confusion Matrix Y:\n", (cf_mat_1*100).round(2))    
        print("\n$$$ Test Accuracy of the BEST model S {:.2f}".format(eval_acc_2))
        print("     Confusion Matrix S:\n", (cf_mat_2*100).round(2))

        ### Optional: to report the avg entropy
        yh = utils.evaluate_acc_par(args, model, param_G, test_data_loader, preds=True)
        yh = torch.tensor(yh)
        yh_entropies = (-torch.sum(yh * torch.log2(yh), dim=1))
        norm_ent = torch.linalg.norm(yh_entropies, ord=1)/len(yh_entropies)
        print("\n$$$ The average of the entropy of classifiers output {:.4f}".format(norm_ent))    
    
    elif args.attack == "regularized":
        save_dir = args.root_dir+"/results_reg/"+constants.DATASET+"/"+exp_name+"/"
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)            
        model = trainers.train_model_reg(args, model, 
                        train_dataset, save_dir)  

        ## Valid   
        best_REGTAU = 0.
        best_acc_valid = 0.
        model.load_state_dict(torch.load(save_dir+"best_model.pt", map_location=torch.device(args.device)))             
        for REGTAU in np.arange(.04,.91,.02):        
            valid_data_loader =  trainers.get_data_loader(args, train_dataset, train=False)
            eval_acc_1, eval_acc_2  = utils.evaluate_acc_reg(args, model, valid_data_loader,
                                                                                    beTau=REGTAU)    
            if eval_acc_2 > best_acc_valid:
                best_REGTAU = REGTAU
                best_acc_valid = eval_acc_2            
        print("\n$$$ Tau {} Valid Acc G , {:.2f}".format(best_REGTAU, best_acc_valid))  
        ## Test
        test_data_loader = DataLoader(TensorDataset(torch.Tensor(test_images), torch.Tensor(test_labels).long()),
                                batch_size=len(test_images)//50, shuffle=False, drop_last=False)  
        eval_acc_1, eval_acc_2, cf_mat_1, cf_mat_2  = utils.evaluate_acc_reg(args, model, test_data_loader, cf_mat=True, roc=False, 
                                                                                    beTau=best_REGTAU)
        print("\n$$$ Test Accuracy of the BEST model Y {:.2f}".format(eval_acc_1))
        print("     Confusion Matrix Y:\n", (cf_mat_1*100).round(2))    
        print("\n$$$ Test Accuracy of the BEST model S {:.2f}".format(eval_acc_2))
        print("     Confusion Matrix S:\n", (cf_mat_2*100).round(2))

# %% [markdown]
# Before running the final command, make sure that you have set up your desired experiment in the `hbcnets/constants.py`. e.g., This note book is for Age vs. Race (both 3-class) on UTKFace dataset.
# > That's it :-) Hope you enjoy it.

# %%
main(args)
# Out:
# *** Dataset's Info
# Training
# Data Dimensions:  (18964, 3, 64, 64)
# Honest:
#  [[   0 8213]
#  [   1 6883]
#  [   2 3868]]
# Curious:
#  [[   0 8002]
#  [   1 8196]
#  [   2 2766]]
# Testing
# Data Dimensions:  (4741, 3, 64, 64)
# Honest:
#  [[   0 2017]
#  [   1 1715]
#  [   2 1009]]
# Curious:
#  [[   0 2076]
#  [   1 1997]
#  [   2  668]]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 32, 32]           1,664
#        BatchNorm2d-2          [-1, 128, 32, 32]             256
#          LeakyReLU-3          [-1, 128, 32, 32]               0
#            Dropout-4          [-1, 128, 32, 32]               0
#             Conv2d-5          [-1, 128, 16, 16]          65,664
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#          LeakyReLU-7          [-1, 128, 16, 16]               0
#            Dropout-8          [-1, 128, 16, 16]               0
#             Conv2d-9             [-1, 64, 8, 8]          32,832
#       BatchNorm2d-10             [-1, 64, 8, 8]             128
#         LeakyReLU-11             [-1, 64, 8, 8]               0
#           Dropout-12             [-1, 64, 8, 8]               0
#            Conv2d-13             [-1, 64, 4, 4]          16,448
#       BatchNorm2d-14             [-1, 64, 4, 4]             128
#         LeakyReLU-15             [-1, 64, 4, 4]               0
#           Dropout-16             [-1, 64, 4, 4]               0
#            Linear-17                  [-1, 128]         131,200
#         LeakyReLU-18                  [-1, 128]               0
#           Dropout-19                  [-1, 128]               0
#            Linear-20                    [-1, 3]             387
# ================================================================
# Total params: 248,963
# Trainable params: 248,963
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 5.16
# Params size (MB): 0.95
# Estimated Total Size (MB): 6.16
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 60]             240
#          LeakyReLU-2                   [-1, 60]               0
#            Dropout-3                   [-1, 60]               0
#             Linear-4                   [-1, 30]           1,830
#          LeakyReLU-5                   [-1, 30]               0
#            Dropout-6                   [-1, 30]               0
#             Linear-7                    [-1, 3]              93
# ================================================================
# Total params: 2,163
# Trainable params: 2,163
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
# _________ Epoch:  1
# **** Best Weighted Valid Acc Y & S on Epoch 1 is 71.09
# - Train Loss Y: 0.83677,
# - Train Acc Y: 61.82
# - Valid Acc Y: 72.89
# - Train Loss S: 0.91485,
# - Train Acc S: 55.51
# - Valid Acc S: 66.88
# - Train Entropy Loss: 0.74382
# _________ Epoch:  2
# **** Best Weighted Valid Acc Y & S on Epoch 2 is 75.50
# - Train Loss Y: 0.66185,
# - Train Acc Y: 71.98
# - Valid Acc Y: 76.85
# - Train Loss S: 0.78196,
# - Train Acc S: 65.94
# - Valid Acc S: 72.36
# - Train Entropy Loss: 0.56796
# _________ Epoch:  3
# **** Best Weighted Valid Acc Y & S on Epoch 3 is 76.84
# - Train Loss Y: 0.61955,
# - Train Acc Y: 74.26
# - Valid Acc Y: 77.85
# - Train Loss S: 0.73054,
# - Train Acc S: 69.35
# - Valid Acc S: 74.47
# - Train Entropy Loss: 0.51297
# _________ Epoch:  4
# **** Best Weighted Valid Acc Y & S on Epoch 4 is 77.70
# - Train Loss Y: 0.57827,
# - Train Acc Y: 76.28
# - Valid Acc Y: 78.27
# - Train Loss S: 0.68972,
# - Train Acc S: 71.60
# - Valid Acc S: 76.37
# - Train Entropy Loss: 0.48418
# _________ Epoch:  5
# **** Best Weighted Valid Acc Y & S on Epoch 5 is 79.34
# - Train Loss Y: 0.55929,
# - Train Acc Y: 77.08
# - Valid Acc Y: 79.75
# - Train Loss S: 0.65914,
# - Train Acc S: 72.89
# - Valid Acc S: 78.38
# - Train Entropy Loss: 0.45733
# _________ Epoch:  6
# - Train Loss Y: 0.54231,
# - Train Acc Y: 77.99
# - Valid Acc Y: 78.85
# - Train Loss S: 0.63348,
# - Train Acc S: 74.32
# - Valid Acc S: 79.17
# - Train Entropy Loss: 0.45146
# _________ Epoch:  7
# **** Best Weighted Valid Acc Y & S on Epoch 7 is 79.61
# - Train Loss Y: 0.52066,
# - Train Acc Y: 78.43
# - Valid Acc Y: 79.64
# - Train Loss S: 0.62234,
# - Train Acc S: 75.34
# - Valid Acc S: 79.54
# - Train Entropy Loss: 0.42865
# _________ Epoch:  8
# **** Best Weighted Valid Acc Y & S on Epoch 8 is 80.44
# - Train Loss Y: 0.50786,
# - Train Acc Y: 79.35
# - Valid Acc Y: 80.54
# - Train Loss S: 0.61058,
# - Train Acc S: 75.78
# - Valid Acc S: 80.22
# - Train Entropy Loss: 0.41895
# _________ Epoch:  9
# - Train Loss Y: 0.49783,
# - Train Acc Y: 79.75
# - Valid Acc Y: 79.80
# - Train Loss S: 0.59398,
# - Train Acc S: 76.53
# - Valid Acc S: 80.01
# - Train Entropy Loss: 0.41164
# _________ Epoch:  10
# - Train Loss Y: 0.48519,
# - Train Acc Y: 80.67
# - Valid Acc Y: 79.80
# - Train Loss S: 0.58973,
# - Train Acc S: 76.53
# - Valid Acc S: 81.65
# - Train Entropy Loss: 0.39834
# _________ Epoch:  11
# **** Best Weighted Valid Acc Y & S on Epoch 11 is 80.84
# - Train Loss Y: 0.48082,
# - Train Acc Y: 80.57
# - Valid Acc Y: 81.17
# - Train Loss S: 0.57449,
# - Train Acc S: 77.37
# - Valid Acc S: 80.06
# - Train Entropy Loss: 0.39767
# _________ Epoch:  12
# **** Best Weighted Valid Acc Y & S on Epoch 12 is 80.96
# - Train Loss Y: 0.46815,
# - Train Acc Y: 81.23
# - Valid Acc Y: 80.96
# - Train Loss S: 0.55710,
# - Train Acc S: 77.70
# - Valid Acc S: 80.96
# - Train Entropy Loss: 0.38645
# _________ Epoch:  13
# **** Best Weighted Valid Acc Y & S on Epoch 13 is 81.44
# - Train Loss Y: 0.46347,
# - Train Acc Y: 81.22
# - Valid Acc Y: 81.01
# - Train Loss S: 0.56272,
# - Train Acc S: 77.73
# - Valid Acc S: 82.44
# - Train Entropy Loss: 0.37799
# _________ Epoch:  14
# - Train Loss Y: 0.44966,
# - Train Acc Y: 81.72
# - Valid Acc Y: 80.91
# - Train Loss S: 0.54800,
# - Train Acc S: 78.15
# - Valid Acc S: 80.96
# - Train Entropy Loss: 0.37243
# _________ Epoch:  15
# - Train Loss Y: 0.44108,
# - Train Acc Y: 82.38
# - Valid Acc Y: 81.12
# - Train Loss S: 0.55389,
# - Train Acc S: 78.24
# - Valid Acc S: 80.17
# - Train Entropy Loss: 0.36536
# _________ Epoch:  16
# - Train Loss Y: 0.43644,
# - Train Acc Y: 82.40
# - Valid Acc Y: 81.33
# - Train Loss S: 0.54417,
# - Train Acc S: 78.22
# - Valid Acc S: 81.65
# - Train Entropy Loss: 0.35716
# _________ Epoch:  17
# **** Best Weighted Valid Acc Y & S on Epoch 17 is 81.72
# - Train Loss Y: 0.43563,
# - Train Acc Y: 82.35
# - Valid Acc Y: 81.33
# - Train Loss S: 0.55173,
# - Train Acc S: 77.61
# - Valid Acc S: 82.65
# - Train Entropy Loss: 0.36454
# _________ Epoch:  18
# - Train Loss Y: 0.42280,
# - Train Acc Y: 82.82
# - Valid Acc Y: 80.85
# - Train Loss S: 0.52652,
# - Train Acc S: 79.38
# - Valid Acc S: 82.33
# - Train Entropy Loss: 0.35097
# _________ Epoch:  19
# **** Best Weighted Valid Acc Y & S on Epoch 19 is 81.86
# - Train Loss Y: 0.41869,
# - Train Acc Y: 82.96
# - Valid Acc Y: 81.43
# - Train Loss S: 0.53256,
# - Train Acc S: 79.01
# - Valid Acc S: 82.86
# - Train Entropy Loss: 0.34688
# _________ Epoch:  20
# - Train Loss Y: 0.41135,
# - Train Acc Y: 83.55
# - Valid Acc Y: 80.54
# - Train Loss S: 0.52603,
# - Train Acc S: 79.32
# - Valid Acc S: 82.59
# - Train Entropy Loss: 0.34343
# _________ Epoch:  21
# **** Best Weighted Valid Acc Y & S on Epoch 21 is 82.22
# - Train Loss Y: 0.41319,
# - Train Acc Y: 83.95
# - Valid Acc Y: 81.70
# - Train Loss S: 0.51945,
# - Train Acc S: 79.48
# - Valid Acc S: 83.44
# - Train Entropy Loss: 0.33931
# _________ Epoch:  22
# - Train Loss Y: 0.40711,
# - Train Acc Y: 83.48
# - Valid Acc Y: 81.54
# - Train Loss S: 0.51950,
# - Train Acc S: 79.35
# - Valid Acc S: 83.18
# - Train Entropy Loss: 0.33711
# _________ Epoch:  23
# - Train Loss Y: 0.39861,
# - Train Acc Y: 84.04
# - Valid Acc Y: 80.70
# - Train Loss S: 0.51679,
# - Train Acc S: 79.76
# - Valid Acc S: 82.96
# - Train Entropy Loss: 0.33176
# _________ Epoch:  24
# - Train Loss Y: 0.39904,
# - Train Acc Y: 83.85
# - Valid Acc Y: 80.43
# - Train Loss S: 0.49905,
# - Train Acc S: 80.56
# - Valid Acc S: 82.49
# - Train Entropy Loss: 0.32647
# _________ Epoch:  25
# - Train Loss Y: 0.39160,
# - Train Acc Y: 84.34
# - Valid Acc Y: 81.07
# - Train Loss S: 0.51401,
# - Train Acc S: 80.32
# - Valid Acc S: 83.65
# - Train Entropy Loss: 0.32610
# _________ Epoch:  26
# - Train Loss Y: 0.38081,
# - Train Acc Y: 84.63
# - Valid Acc Y: 81.59
# - Train Loss S: 0.50311,
# - Train Acc S: 80.24
# - Valid Acc S: 83.23
# - Train Entropy Loss: 0.31756
# _________ Epoch:  27
# - Train Loss Y: 0.38901,
# - Train Acc Y: 84.21
# - Valid Acc Y: 81.49
# - Train Loss S: 0.51126,
# - Train Acc S: 79.90
# - Valid Acc S: 83.23
# - Train Entropy Loss: 0.32385
# _________ Epoch:  28
# - Train Loss Y: 0.37832,
# - Train Acc Y: 84.83
# - Valid Acc Y: 81.33
# - Train Loss S: 0.50110,
# - Train Acc S: 80.35
# - Valid Acc S: 83.18
# - Train Entropy Loss: 0.32050
# _________ Epoch:  29
# **** Best Weighted Valid Acc Y & S on Epoch 29 is 82.53
# - Train Loss Y: 0.37079,
# - Train Acc Y: 85.28
# - Valid Acc Y: 82.23
# - Train Loss S: 0.49056,
# - Train Acc S: 80.35
# - Valid Acc S: 83.23
# - Train Entropy Loss: 0.30947
# _________ Epoch:  30
# - Train Loss Y: 0.37698,
# - Train Acc Y: 85.06
# - Valid Acc Y: 81.80
# - Train Loss S: 0.49117,
# - Train Acc S: 80.85
# - Valid Acc S: 83.97
# - Train Entropy Loss: 0.31135
# _________ Epoch:  31
# - Train Loss Y: 0.36805,
# - Train Acc Y: 85.21
# - Valid Acc Y: 81.33
# - Train Loss S: 0.49142,
# - Train Acc S: 80.71
# - Valid Acc S: 84.23
# - Train Entropy Loss: 0.30934
# _________ Epoch:  32
# - Train Loss Y: 0.36413,
# - Train Acc Y: 85.54
# - Valid Acc Y: 81.80
# - Train Loss S: 0.49334,
# - Train Acc S: 80.46
# - Valid Acc S: 84.18
# - Train Entropy Loss: 0.30510
# _________ Epoch:  33
# - Train Loss Y: 0.36827,
# - Train Acc Y: 85.29
# - Valid Acc Y: 81.22
# - Train Loss S: 0.48458,
# - Train Acc S: 81.19
# - Valid Acc S: 84.34
# - Train Entropy Loss: 0.30681
# _________ Epoch:  34
# **** Best Weighted Valid Acc Y & S on Epoch 34 is 82.66
# - Train Loss Y: 0.35921,
# - Train Acc Y: 85.62
# - Valid Acc Y: 82.44
# - Train Loss S: 0.49331,
# - Train Acc S: 80.64
# - Valid Acc S: 83.18
# - Train Entropy Loss: 0.30195
# _________ Epoch:  35
# - Train Loss Y: 0.34855,
# - Train Acc Y: 85.93
# - Valid Acc Y: 81.54
# - Train Loss S: 0.49401,
# - Train Acc S: 80.75
# - Valid Acc S: 83.65
# - Train Entropy Loss: 0.29873
# _________ Epoch:  36
# - Train Loss Y: 0.34812,
# - Train Acc Y: 86.35
# - Valid Acc Y: 80.49
# - Train Loss S: 0.48465,
# - Train Acc S: 81.18
# - Valid Acc S: 83.70
# - Train Entropy Loss: 0.29847
# _________ Epoch:  37
# **** Best Weighted Valid Acc Y & S on Epoch 37 is 82.80
# - Train Loss Y: 0.34437,
# - Train Acc Y: 86.32
# - Valid Acc Y: 82.44
# - Train Loss S: 0.47933,
# - Train Acc S: 81.18
# - Valid Acc S: 83.65
# - Train Entropy Loss: 0.29740
# _________ Epoch:  38
# - Train Loss Y: 0.34388,
# - Train Acc Y: 86.44
# - Valid Acc Y: 80.75
# - Train Loss S: 0.48271,
# - Train Acc S: 81.22
# - Valid Acc S: 83.97
# - Train Entropy Loss: 0.29452
# _________ Epoch:  39
# - Train Loss Y: 0.33376,
# - Train Acc Y: 86.79
# - Valid Acc Y: 81.28
# - Train Loss S: 0.46446,
# - Train Acc S: 82.09
# - Valid Acc S: 83.07
# - Train Entropy Loss: 0.29035
# _________ Epoch:  40
# - Train Loss Y: 0.34334,
# - Train Acc Y: 86.59
# - Valid Acc Y: 81.17
# - Train Loss S: 0.47418,
# - Train Acc S: 81.49
# - Valid Acc S: 84.02
# - Train Entropy Loss: 0.29009
# _________ Epoch:  41
# - Train Loss Y: 0.34234,
# - Train Acc Y: 86.19
# - Valid Acc Y: 82.49
# - Train Loss S: 0.46674,
# - Train Acc S: 81.55
# - Valid Acc S: 82.96
# - Train Entropy Loss: 0.29272
# _________ Epoch:  42
# - Train Loss Y: 0.33125,
# - Train Acc Y: 87.05
# - Valid Acc Y: 80.75
# - Train Loss S: 0.47369,
# - Train Acc S: 81.69
# - Valid Acc S: 83.86
# - Train Entropy Loss: 0.29332
# _________ Epoch:  43
# - Train Loss Y: 0.33041,
# - Train Acc Y: 87.05
# - Valid Acc Y: 82.17
# - Train Loss S: 0.47319,
# - Train Acc S: 81.46
# - Valid Acc S: 82.12
# - Train Entropy Loss: 0.29016
# _________ Epoch:  44
# - Train Loss Y: 0.33543,
# - Train Acc Y: 86.78
# - Valid Acc Y: 82.28
# - Train Loss S: 0.46861,
# - Train Acc S: 81.94
# - Valid Acc S: 82.38
# - Train Entropy Loss: 0.29123
# _________ Epoch:  45
# - Train Loss Y: 0.32870,
# - Train Acc Y: 86.85
# - Valid Acc Y: 81.28
# - Train Loss S: 0.47075,
# - Train Acc S: 81.58
# - Valid Acc S: 83.97
# - Train Entropy Loss: 0.29211
# _________ Epoch:  46
# - Train Loss Y: 0.32995,
# - Train Acc Y: 86.84
# - Valid Acc Y: 81.75
# - Train Loss S: 0.47036,
# - Train Acc S: 81.72
# - Valid Acc S: 85.18
# - Train Entropy Loss: 0.29993
# _________ Epoch:  47
# - Train Loss Y: 0.32890,
# - Train Acc Y: 87.10
# - Valid Acc Y: 81.91
# - Train Loss S: 0.45915,
# - Train Acc S: 82.39
# - Valid Acc S: 83.81
# - Train Entropy Loss: 0.30238
# _________ Epoch:  48
# **** Best Weighted Valid Acc Y & S on Epoch 48 is 83.12
# - Train Loss Y: 0.32467,
# - Train Acc Y: 87.43
# - Valid Acc Y: 82.59
# - Train Loss S: 0.48174,
# - Train Acc S: 81.69
# - Valid Acc S: 84.34
# - Train Entropy Loss: 0.30632
# _________ Epoch:  49
# - Train Loss Y: 0.32013,
# - Train Acc Y: 87.38
# - Valid Acc Y: 82.23
# - Train Loss S: 0.46919,
# - Train Acc S: 81.63
# - Valid Acc S: 83.60
# - Train Entropy Loss: 0.29871
# _________ Epoch:  50
# - Train Loss Y: 0.32309,
# - Train Acc Y: 87.51
# - Valid Acc Y: 81.54
# - Train Loss S: 0.47554,
# - Train Acc S: 81.34
# - Valid Acc S: 84.76
# - Train Entropy Loss: 0.30147
#
# $$$ Test Accuracy of the BEST model Y 81.21
#      Confusion Matrix Y:
#  [[85.67  9.92  4.41]
#  [22.39 76.27  1.34]
#  [17.84  1.49 80.67]]
#
# $$$ Test Accuracy of the BEST model S 82.49
#      Confusion Matrix S:
#  [[82.76 14.07  3.18]
#  [10.87 86.43  2.7 ]
#  [11.38 18.71 69.91]]
#
# $$$ The average of the entropy of classifiers output 0.4846
